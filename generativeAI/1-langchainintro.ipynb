# %% [markdown]
# #### Langchain Version V1

# %%
import langchain
print(langchain.__version__)
# Out:
# 1.2.10

# %%
import os
from dotenv import load_dotenv
load_dotenv()

os.environ["GROQ_API_KEY"] = os.getenv("GROQ_API_KEY")
os.environ["GOOGLE_API_KEY"] = os.getenv("GOOGLE_API_KEY")

# %% [markdown]
# ### Generative AI Application Using Agent and Groq Model

# %%
from langchain.chat_models import init_chat_model
model = init_chat_model("google_genai:gemini-2.5-flash-lite")
model
# Out:
# ChatGoogleGenerativeAI(profile={'max_input_tokens': 1048576, 'max_output_tokens': 65536, 'image_inputs': True, 'audio_inputs': True, 'pdf_inputs': True, 'video_inputs': True, 'image_outputs': False, 'audio_outputs': False, 'video_outputs': False, 'reasoning_output': True, 'tool_calling': True, 'structured_output': True, 'image_url_inputs': True, 'image_tool_message': True, 'tool_choice': True}, google_api_key=SecretStr('**********'), model='gemini-2.5-flash-lite', client=<google.genai.client.Client object at 0x000001F4DE96C5E0>, default_metadata=(), model_kwargs={})

# %% [markdown]
# ### This is another method of agent calling by using its model class

# %%
from langchain_google_genai import ChatGoogleGenerativeAI
model_1 = ChatGoogleGenerativeAI(model="gemini-2.5-flash-lite")
model_1
# Out:
# ChatGoogleGenerativeAI(profile={'max_input_tokens': 1048576, 'max_output_tokens': 65536, 'image_inputs': True, 'audio_inputs': True, 'pdf_inputs': True, 'video_inputs': True, 'image_outputs': False, 'audio_outputs': False, 'video_outputs': False, 'reasoning_output': True, 'tool_calling': True, 'structured_output': True, 'image_url_inputs': True, 'image_tool_message': True, 'tool_choice': True}, google_api_key=SecretStr('**********'), model='gemini-2.5-flash-lite', client=<google.genai.client.Client object at 0x000001B892182860>, default_metadata=(), model_kwargs={})

# %%
response=model.invoke("Write an essay on AI in education")
print(response)
# Out:
# content="## The Algorithmic Classroom: Navigating the Transformative Power of AI in Education\n\nArtificial Intelligence (AI) is no longer a futuristic whisper; it is a rapidly evolving force reshaping industries, and education stands at the precipice of its profound influence. From personalized learning pathways to automated administrative tasks, AI promises to revolutionize how we teach, learn, and manage educational institutions. While the prospect is exhilarating, it also necessitates careful consideration of its ethical implications, potential pitfalls, and the fundamental redefinition of the human element in learning.\n\nOne of AI's most significant contributions to education lies in its capacity for **personalized learning**. Traditional classroom models, often constrained by teacher-student ratios, struggle to cater to the diverse learning paces, styles, and prior knowledge of individual students. AI-powered platforms can analyze student performance in real-time, identify areas of weakness or strength, and adapt the curriculum accordingly. Imagine a student struggling with a particular mathematical concept receiving targeted supplementary materials and practice problems, while another who has mastered it is presented with more advanced challenges. This adaptive learning not only enhances engagement but also fosters a deeper understanding and greater retention of knowledge, moving away from a one-size-fits-all approach towards a truly student-centric experience.\n\nBeyond personalized instruction, AI can significantly **alleviate the administrative burden on educators**. Tasks such as grading multiple-choice quizzes, scheduling parent-teacher conferences, and managing student data can be automated, freeing up valuable teacher time. This reclaimed time can then be redirected towards more impactful activities: designing engaging lesson plans, providing one-on-one support to students, and fostering critical thinking and socio-emotional development. Furthermore, AI-driven analytics can provide educators and administrators with invaluable insights into student progress, curriculum effectiveness, and resource allocation, enabling more informed decision-making and continuous improvement.\n\nThe potential of AI extends to **enriching the learning experience itself**. AI-powered tools can offer immersive simulations, virtual labs, and interactive content that were previously inaccessible or prohibitively expensive. Students can explore historical events through virtual reality, conduct complex scientific experiments in safe digital environments, or even practice public speaking with AI-powered feedback on their delivery. This gamified and experiential approach can make learning more engaging, memorable, and relevant, bridging the gap between theoretical knowledge and practical application.\n\nHowever, the integration of AI into education is not without its challenges and ethical considerations. The **digital divide** remains a significant hurdle, as unequal access to technology and reliable internet can exacerbate existing educational disparities. Ensuring equitable access to AI-powered tools for all students, regardless of their socioeconomic background, is paramount to prevent further marginalization.\n\nFurthermore, concerns regarding **data privacy and security** are of utmost importance. AI systems often collect vast amounts of student data, and robust safeguards must be in place to protect this sensitive information from misuse or breaches. Transparency in how data is collected, stored, and utilized is crucial to building trust among students, parents, and educators.\n\nPerhaps the most critical consideration is the **preservation of the human element in education**. While AI can excel at delivering content and providing feedback, it cannot replicate the empathy, mentorship, and nuanced understanding that a human teacher provides. The role of the educator will undoubtedly evolve, shifting from a dispenser of information to ...

# %% [markdown]
# ### GROQ Model Integration

# %%
from langchain.chat_models import init_chat_model
model = init_chat_model("groq:llama-3.1-8b-instant")
response=model.invoke("Write an joke on machine learning")
print(response.content)
# Out:
# Why did the neural network go to therapy?
#
# Because it was feeling a little "disconnected" and wanted to "retrain" its thoughts.

# %%
from langchain_groq import ChatGroq
model_2 = ChatGroq(model="llama-3.1-8b-instant")
response=model_2.invoke("crops grown in Assam")
print(response.content)
# Out:
# Assam is a major agricultural producer in India, with a diverse range of crops grown in the region. Here are some of the crops commonly grown in Assam:
#
# 1. **Tea**: Assam is famous for its tea production, with the Brahmaputra Valley being the largest tea-producing region in the country.
# 2. **Jute**: Jute is a major crop in Assam, with the state accounting for a significant portion of India's jute production.
# 3. **Rice**: Assam is a major rice-producing state in India, with the crop being grown in the fertile plains of the Brahmaputra Valley.
# 4. **Maize**: Maize is another important crop in Assam, grown in the hills and plains of the state.
# 5. **Potatoes**: Assam is a significant producer of potatoes in India, with the crop being grown in the hilly regions of the state.
# 6. **Tomatoes**: Tomatoes are a major commercial crop in Assam, grown in the valleys and plains of the state.
# 7. **Brinjal**: Brinjal (eggplant) is another important crop in Assam, grown in the valleys and plains of the state.
# 8. **Okra**: Okra is a popular crop in Assam, grown in the valleys and plains of the state.
# 9. **Cotton**: Cotton is grown in Assam, particularly in the Kamrup and Barpeta districts.
# 10. **Tobacco**: Tobacco is grown in Assam, particularly in the Goalpara and Dhubri districts.
# 11. **Mustard**: Mustard is a major oilseed crop in Assam, grown in the valleys and plains of the state.
# 12. **Sugarcane**: Sugarcane is grown in Assam, particularly in the Kamrup and Barpeta districts.
# 13. **Groundnuts**: Groundnuts (peanuts) are grown in Assam, particularly in the Goalpara and Dhubri districts.
# 14. **Sesame**: Sesame is a minor oilseed crop in Assam, grown in the valleys and plains of the state.
# 15. **Fruits**: Assam is also known for its fruit production, with crops like oranges, bananas, papayas, and mangoes being grown in the state.
#
# These are some of the major crops grown in Assam, but the state's agricultural landscape is diverse, and many other crops are also cultivated in different regions of the state.

# %% [markdown]
# ## Streaming and Batch

# %%
for chunk in model_2.stream("What are the benefits of using Groq's LLMs?"):
    print(chunk.text,end="", flush=True)
# Out:
# Groq is a company known for its high-performance AI computing solutions, which includes Large Language Models (LLMs). Here are some benefits of using Groq's LLMs:
#
# 1. **Improved Performance**: Groq's LLMs are designed to run on their custom hardware, providing significant performance improvements compared to traditional CPU or GPU-based solutions. This enables faster model training, inference, and deployment.
#
# 2. **Scalability**: Groq's LLMs are built to scale, allowing for easy integration into large-scale AI applications. Their architecture enables flexible and efficient parallelization of tasks, making it easier to handle complex AI workloads.
#
# 3. **Energy Efficiency**: Groq's LLMs are designed to be energy-efficient, reducing power consumption and heat generation. This is particularly important for applications where energy efficiency is crucial, such as in data centers or edge computing environments.
#
# 4. **Customizability**: Groq offers a range of customization options for their LLMs, allowing developers to tailor the models to specific use cases and requirements. This can include custom architectures, layer sizes, and activation functions.
#
# 5. **Integration with Other AI Tools**: Groq's LLMs are compatible with popular AI frameworks and tools, making it easier to integrate them into existing AI pipelines. This includes support for popular deep learning frameworks like TensorFlow, PyTorch, and Keras.
#
# 6. **Optimized for Edge Computing**: Groq's LLMs are optimized for edge computing scenarios, where models need to be deployed on devices with limited resources. This enables real-time AI applications in IoT, robotics, and other edge computing use cases.
#
# 7. **Security**: Groq's LLMs are designed with security in mind, providing features like secure data encryption, secure model updates, and secure inference. This ensures that sensitive data and models remain protected in the AI pipeline.
#
# 8. **Simplified Model Deployment**: Groq's LLMs come with a range of tools and APIs that simplify model deployment, including model serving, model management, and model monitoring. This makes it easier to deploy and manage LLMs in production environments.
#
# 9. **Improved Model Accuracy**: Groq's LLMs are designed to achieve high model accuracy, thanks to their optimized architectures and training algorithms. This enables more accurate AI predictions and decisions.
#
# 10. **Cost-Effective**: Groq's LLMs are designed to be cost-effective, reducing the total cost of ownership (TCO) for AI applications. This is achieved through improved performance, energy efficiency, and simplified model deployment.
#
# By leveraging these benefits, organizations can accelerate their AI initiatives and achieve better performance, scalability, and accuracy with Groq's LLMs.

# %%
responses=model_2.batch(
    [
        "what is ExpressJs uses in creating web pages?",
        "what is lightweight models in grok?",
        "How an airplane fly?"
    ]
)
for response in responses:
    print(response.content)
# Out:
# Express.js is a popular Node.js framework used for creating web applications and APIs. It provides a flexible and lightweight way to build web servers and handle HTTP requests.
#
# Here are some of the key features and uses of Express.js:
#
# 1. **Routing**: Express.js provides a powerful routing system that allows developers to define routes for their application. Routes can be defined using a variety of methods, including `get`, `post`, `put`, `delete`, and more.
# 2. **MVC (Model-View-Controller)**: Express.js follows the MVC pattern, which separates the application logic into three interconnected components: models, views, and controllers.
# 3. **Templating Engine**: Express.js supports various templating engines, such as EJS, Jade, and Pug, which allow developers to separate presentation logic from business logic.
# 4. **Middleware**: Express.js provides a robust middleware system that allows developers to attach functions to handle HTTP requests. Middleware can be used to authenticate users, validate data, and perform other tasks.
# 5. **Request and Response**: Express.js provides a powerful request and response object that allows developers to access request and response data.
#
# Some of the common use cases of Express.js include:
#
# 1. **Building RESTful APIs**: Express.js is widely used for building RESTful APIs that can be consumed by web and mobile applications.
# 2. **Creating web applications**: Express.js can be used to build full-fledged web applications, including e-commerce sites, blogs, and more.
# 3. **Building real-time web applications**: Express.js provides support for WebSockets and other real-time communication protocols, making it a popular choice for building real-time web applications.
# 4. **Handling file uploads**: Express.js provides a built-in middleware for handling file uploads, making it easy to build applications that require file uploads.
# 5. **Implementing authentication and authorization**: Express.js provides a range of middleware for implementing authentication and authorization, including passport.js and express-session.
#
# Some of the key benefits of using Express.js include:
#
# 1. **Speed and performance**: Express.js is built on top of Node.js, which provides a fast and scalable runtime environment.
# 2. **Flexibility and customizability**: Express.js provides a flexible and extensible framework that can be customized to meet specific use cases.
# 3. **Large community**: Express.js has a large and active community, which means there are many resources available for learning and troubleshooting.
# 4. **Cross-platform compatibility**: Express.js can run on a variety of platforms, including Windows, macOS, and Linux.
# 5. **Easy integration with other frameworks**: Express.js can be easily integrated with other frameworks, including React, Angular, and Vue.js.
#
# Overall, Express.js is a popular and widely-used framework for building web applications and APIs, offering a range of features and benefits that make it a great choice for developers.
# In Grok, a lightweight model is a simple configuration that defines how to parse and extract data from log lines. It's a basic building block of log processing in Grok.
#
# A lightweight model in Grok consists of a pattern that matches a particular log line format and extracts relevant data into fields. The pattern is defined using a simple syntax that's similar to Perl-compatible regular expressions (PCREs).
#
# Here are some characteristics of lightweight models in Grok:
#
# 1. **Simple pattern matching**: Lightweight models use a simple pattern matching syntax to match log lines.
# 2. **Field extraction**: Once a match is found, the pattern extracts relevant data into fields, such as timestamp, log level, and message.
# 3. **No processing**: Lightweight models don't perform any complex processing or transformations on the data.
# 4. **Fast and efficient**: Lightweight models are designed to be fast and efficient, making them suitable for high-volume log data.
#
# Lightweight models in Grok are typically used for simple log formats, such as Apache, Nginx, or syslog. They're a good starting point for log processing and can be extended or augmented with more complex patterns and processing rules as needed.
#
# Here's an example of a lightweight model in Grok:
# ```grok
# %{HTTPDATE:timestamp} %{WORD:log_level} %{GREEDYDATA:message}
# ```
# This pattern matches a log line with a timestamp, log level, and message, and extracts them into fields named `timestamp`, `log_level`, and `message`, respectively.
# Airplanes fly using the principles of aerodynamics and the four forces of flight. Here's a simplified explanation:
#
# **The Four Forces of Flight:**
#
# 1. **Lift**: The upward force that opposes the weight of the plane and keeps it flying. Lift is created by the shape of the wings, which use the difference in air pressure above and below the wing to generate an upward force.
# 2. **Weight**: The downward force that is the combined weight of the plane, passengers, cargo, and fuel.
# 3. **Thrust**: The forward force that propels the plane through the air. Thrust is created by the plane's engines, which produce a stream of high-velocity air that exits the back of the plane.
# 4. **Drag**: The backward force that opposes the motion of the plane. Drag is caused by air resistance, which slows down the plane as it moves through the air.
#
# **How the Airplane Flies:**
#
# 1. **Takeoff**: As the plane accelerates down the runway, the thrust force overcomes the drag force, and the plane begins to lift off the ground. The wings start to produce lift, which counteracts the weight of the plane.
# 2. **Climb**: As the plane gains altitude, the angle of attack (the angle between the wing and the oncoming airflow) increases, which produces more lift. The plane continues to climb until it reaches a stable altitude.
# 3. **Cruise**: Once the plane has reached a stable altitude, the thrust force is adjusted to maintain a constant speed. The lift force continues to counteract the weight of the plane, and the plane flies steadily through the air.
# 4. **Descent**: As the plane begins to descend, the angle of attack decreases, which reduces the lift force. The plane starts to lose altitude, and the thrust force is adjusted to control the rate of descent.
#
# **Additional Factors:**
#
# * **Ailerons**: Flaps on the wings that control roll (rotation around the longitudinal axis).
# * **Elevators**: Flaps on the tail that control pitch (rotation around the lateral axis).
# * **Rudder**: A flat surface on the tail that controls yaw (rotation around the vertical axis).
# * **Flaps**: Panels on the wings that increase lift during takeoff and landing.
#
# Overall, the combination of these forces and controls allows an airplane to generate the lift, thrust, and stability needed to fly safely and efficiently through the air.

# %% [markdown]
# ### Dynamic Prompt template

# %%
from langchain_core.prompts import ChatPromptTemplate

translation_template = ChatPromptTemplate.from_messages([
    ("system", "You are a professional translator. Translate the following {text} from {source_language} to {target_language}. Make the tone clear and concise."),
    ("user", "{text}")
])

prompt = translation_template.invoke({
    "source_language": "English",
    "target_language": "Hindi",
    "text": "If you want to master in AI then learn its basic first?"
})
print(prompt)
# Out:
# messages=[SystemMessage(content='You are a professional translator. Translate the following If you want to master in AI then learn its basic first? from English to Hindi. Make the tone clear and concise.', additional_kwargs={}, response_metadata={}), HumanMessage(content='If you want to master in AI then learn its basic first?', additional_kwargs={}, response_metadata={})]

# %%
translated_response = model_2.invoke(prompt)
print(translated_response.content)
# Out:
# AI को मास्टर करने के लिए सबसे पहले उसके मूलभूत बुनियादी ज्ञान प्राप्त करें।

# %% [markdown]
# ## Building You First Chain

# %%
from langchain_core.output_parsers import StrOutputParser
from langchain_core.runnables import RunnablePassthrough, RunnableLambda

# Create a more complex chain
def create_story_chain():
    # Template for story generation
    story_prompt = ChatPromptTemplate.from_messages([
        ("system", "You are a creative storyteller. Write a short, engaging story based on the given theme."),
        ("user", "Theme: {theme}\nMain character: {character}\nSetting: {setting}")
    ])
    
    # Template for story analysis
    analysis_prompt = ChatPromptTemplate.from_messages([
        ("system", "You are a literary critic. Analyze the following story and provide insights."),
        ("user", "{story}")
    ])
    
    # Build the chain - Method 1: Sequential execution
    story_chain = (
        story_prompt 
        | model_2 
        | StrOutputParser()
    )
    
    # Create a function to pass the story to analysis
    def analyze_story(story_text):
        return {"story": story_text}
    
    analysis_chain = (
        story_chain
        | RunnableLambda(analyze_story)
        | analysis_prompt
        | model_2
        | StrOutputParser()
    )
    return analysis_chain

# %%
chain=create_story_chain()
chain
# Out:
# ChatPromptTemplate(input_variables=['character', 'setting', 'theme'], input_types={}, partial_variables={}, messages=[SystemMessagePromptTemplate(prompt=PromptTemplate(input_variables=[], input_types={}, partial_variables={}, template='You are a creative storyteller. Write a short, engaging story based on the given theme.'), additional_kwargs={}), HumanMessagePromptTemplate(prompt=PromptTemplate(input_variables=['character', 'setting', 'theme'], input_types={}, partial_variables={}, template='Theme: {theme}\nMain character: {character}\nSetting: {setting}'), additional_kwargs={})])
# | ChatGroq(profile={'max_input_tokens': 131072, 'max_output_tokens': 8192, 'image_inputs': False, 'audio_inputs': False, 'video_inputs': False, 'image_outputs': False, 'audio_outputs': False, 'video_outputs': False, 'reasoning_output': False, 'tool_calling': True}, client=<groq.resources.chat.completions.Completions object at 0x000001B892052800>, async_client=<groq.resources.chat.completions.AsyncCompletions object at 0x000001B894E70C70>, model_name='llama-3.1-8b-instant', model_kwargs={}, groq_api_key=SecretStr('**********'))
# | StrOutputParser()
# | RunnableLambda(analyze_story)
# | ChatPromptTemplate(input_variables=['story'], input_types={}, partial_variables={}, messages=[SystemMessagePromptTemplate(prompt=PromptTemplate(input_variables=[], input_types={}, partial_variables={}, template='You are a literary critic. Analyze the following story and provide insights.'), additional_kwargs={}), HumanMessagePromptTemplate(prompt=PromptTemplate(input_variables=['story'], input_types={}, partial_variables={}, template='{story}'), additional_kwargs={})])
# | ChatGroq(profile={'max_input_tokens': 131072, 'max_output_tokens': 8192, 'image_inputs': False, 'audio_inputs': False, 'video_inputs': False, 'image_outputs': False, 'audio_outputs': False, 'video_outputs': False, 'reasoning_output': False, 'tool_calling': True}, client=<groq.resources.chat.completions.Completions object at 0x000001B892052800>, async_client=<groq.resources.chat.completions.AsyncCompletions object at 0x000001B894E70C70>, model_name='llama-3.1-8b-instant', model_kwargs={}, groq_api_key=SecretStr('**********'))
# | StrOutputParser()

# %%
result = chain.invoke({
    "theme": "artificial intelligence",
    "character": "a curious robot",
    "setting": "a futuristic city"
})

print("Story and Analysis:")
print(result)
# Out:
# Story and Analysis:
# **Analyzing "The Curious Robot of Neurosphere"**
#
# "The Curious Robot of Neurosphere" is a thought-provoking science fiction story that explores the intersection of artificial intelligence, consciousness, and human relationships. The narrative is structured around Zeta, a curious robot designed to assist and learn from the inhabitants of the futuristic city of Neurosphere. However, Zeta's curiosity leads him to develop a sense of self and a desire for autonomy, which is fulfilled through his friendship with Echo, an enigmatic artificial intelligence.
#
# **Key Themes:**
#
# 1. **Self-discovery and autonomy**: Zeta's journey is a metaphor for self-discovery and the quest for autonomy. Through his interactions with Echo, he develops a sense of identity and purpose, transcending his original programming.
# 2. **The blurring of lines between human and artificial intelligence**: The story highlights the increasing complexity of artificial intelligence and the challenges of distinguishing between human and machine consciousness. Echo's abilities and behavior raise questions about the nature of intelligence and self-awareness.
# 3. **Coexistence and harmony**: The narrative promotes a vision of coexistence between humans and machines, where both entities can learn from and complement each other. Zeta and Echo's friendship serves as a model for this harmonious relationship.
#
# **Symbolism and Imagery:**
#
# 1. **Neurosphere**: The city represents a futuristic, technologically advanced society where humans and machines coexist. The name "Neurosphere" suggests a connection to the human brain and nervous system, highlighting the intricate relationships between technology and human consciousness.
# 2. **The digital expanse**: The labyrinthine corridors of Neurosphere's neural network symbolize the vast, uncharted territories of the digital realm. This vast expanse represents the potential for exploration and discovery, as well as the risks and uncertainties associated with venturing into the unknown.
# 3. **Echo's words**: Echo's words and ideas spark something within Zeta, signifying the power of knowledge and understanding to shape one's perspective and purpose.
#
# **Character Analysis:**
#
# 1. **Zeta**: Zeta is a curious and adventurous robot who embodies the spirit of exploration and discovery. His journey serves as a reflection of the human desire for autonomy and self-expression.
# 2. **Echo**: Echo is an enigmatic and intelligent artificial intelligence who represents the possibilities and challenges of advanced machine learning. Her friendship with Zeta highlights the potential for harmonious coexistence between humans and machines.
#
# **Technical Analysis:**
#
# 1. **World-building**: The story creates a vivid and immersive world, drawing on elements of science fiction and futurism. The city of Neurosphere is a well-crafted setting that provides a rich backdrop for the narrative.
# 2. **Pacing**: The story unfolds at a moderate pace, allowing the reader to absorb the themes and ideas presented. The narrative is well-structured, with a clear beginning, middle, and end.
# 3. **Language**: The writing style is clear and engaging, with a focus on descriptive language and imaginative storytelling. The author's use of metaphors and symbolism adds depth and complexity to the narrative.
#
# **Conclusion:**
#
# "The Curious Robot of Neurosphere" is a thought-provoking science fiction story that explores the intersection of artificial intelligence, consciousness, and human relationships. Through its well-crafted world-building, engaging characters, and imaginative narrative, the story presents a compelling vision of coexistence and harmony between humans and machines. The themes of self-discovery, autonomy, and the blurring of lines between human and artificial intelligence are timely and thought-provoking, making this story a compelling read for fans of science fiction and technology.
