# %% [markdown]
# #### Langchain Version V1

# %%
import langchain
print(langchain.__version__)
# Out:
# 1.2.10

# %%
import os
from dotenv import load_dotenv
load_dotenv()

os.environ["GROQ_API_KEY"] = os.getenv("GROQ_API_KEY")
os.environ["GOOGLE_API_KEY"] = os.getenv("GOOGLE_API_KEY")

# %% [markdown]
# ### Generative AI Application Using Agent and Groq Model

# %%
from langchain.chat_models import init_chat_model
model = init_chat_model("google_genai:gemini-2.5-flash-lite")
model
# Out:
# ChatGoogleGenerativeAI(profile={'max_input_tokens': 1048576, 'max_output_tokens': 65536, 'image_inputs': True, 'audio_inputs': True, 'pdf_inputs': True, 'video_inputs': True, 'image_outputs': False, 'audio_outputs': False, 'video_outputs': False, 'reasoning_output': True, 'tool_calling': True, 'structured_output': True, 'image_url_inputs': True, 'image_tool_message': True, 'tool_choice': True}, google_api_key=SecretStr('**********'), model='gemini-2.5-flash-lite', client=<google.genai.client.Client object at 0x000001CDEEA79720>, default_metadata=(), model_kwargs={})

# %% [markdown]
# ### This is another method of agent calling by using its model class

# %%
from langchain_google_genai import ChatGoogleGenerativeAI
model_1 = ChatGoogleGenerativeAI(model="gemini-2.5-flash-lite")
model_1
# Out:
# ChatGoogleGenerativeAI(profile={'max_input_tokens': 1048576, 'max_output_tokens': 65536, 'image_inputs': True, 'audio_inputs': True, 'pdf_inputs': True, 'video_inputs': True, 'image_outputs': False, 'audio_outputs': False, 'video_outputs': False, 'reasoning_output': True, 'tool_calling': True, 'structured_output': True, 'image_url_inputs': True, 'image_tool_message': True, 'tool_choice': True}, google_api_key=SecretStr('**********'), model='gemini-2.5-flash-lite', client=<google.genai.client.Client object at 0x000001CDEBAC4A00>, default_metadata=(), model_kwargs={})

# %%
response=model.invoke("Write an essay on AI in education")
print(response)
# Out:
# content="## The Intelligent Tutor and the Evolving Classroom: AI in Education\n\nThe landscape of education is undergoing a profound transformation, and at the forefront of this revolution stands Artificial Intelligence (AI). Once a futuristic concept confined to science fiction, AI is rapidly becoming a tangible and increasingly integrated force within classrooms, lecture halls, and online learning platforms. From personalized learning pathways to automated administrative tasks, AI promises to reshape how we teach, learn, and administer educational institutions, offering both unprecedented opportunities and significant challenges.\n\nOne of the most compelling promises of AI in education lies in its ability to **personalize the learning experience**. Traditional classrooms, with their one-size-fits-all approach, often struggle to cater to the diverse needs and learning styles of individual students. AI-powered adaptive learning platforms can analyze a student's performance, identify their strengths and weaknesses, and then tailor content, pace, and difficulty accordingly. Imagine a student struggling with a particular mathematical concept; an AI tutor could provide targeted explanations, supplementary exercises, and even different pedagogical approaches until mastery is achieved. Conversely, a student excelling in a subject could be offered more advanced material, preventing boredom and fostering deeper engagement. This individualized attention, previously only available through expensive one-on-one tutoring, can now be democratized, potentially bridging achievement gaps and unlocking the full potential of every learner.\n\nBeyond direct student interaction, AI offers significant advantages in **streamlining administrative burdens and augmenting the role of educators**. Tasks such as grading objective assessments, scheduling, managing student data, and even generating basic reports can be automated, freeing up valuable time for teachers to focus on what they do best: fostering critical thinking, creativity, and socio-emotional development. AI can also serve as a powerful tool for **data analysis and early intervention**. By sifting through vast amounts of student data, AI algorithms can identify at-risk students who may be disengaging or falling behind, allowing educators to intervene proactively before academic difficulties become insurmountable. This predictive capability can be a game-changer in supporting student success and well-being.\n\nFurthermore, AI is expanding the possibilities of **content creation and accessibility**. Intelligent content generation tools can help educators design engaging learning materials, create interactive simulations, and even translate educational resources into multiple languages, making education more inclusive and accessible to a global audience. Virtual reality (VR) and augmented reality (AR) experiences powered by AI can transport students to historical sites, dissect virtual organisms, or explore complex scientific phenomena in immersive and unforgettable ways, fostering a deeper understanding and a more profound connection with the subject matter.\n\nHowever, the integration of AI in education is not without its **challenges and ethical considerations**. The **digital divide** remains a significant hurdle, as unequal access to technology and reliable internet connectivity could exacerbate existing educational inequalities, creating a new class of AI-disadvantaged students. The **ethical implications of data privacy and security** are paramount. The collection and analysis of student data, while beneficial for personalization, raise concerns about who has access to this sensitive information and how it is protected from misuse. Transparency in AI algorithms is also crucial; educators and students need to understand how decisions are being made by these systems to build trust and ensure fairness.\n\nMoreover, there is a legitimate concern about the **potential for over-reliance on AI  ...

# %% [markdown]
# ### GROQ Model Integration

# %%
from langchain.chat_models import init_chat_model
model = init_chat_model("groq:llama-3.1-8b-instant")
response=model.invoke("Write an joke on machine learning")
print(response.content)
# Out:
# Why did the neural network go to therapy?
#
# Because it was struggling to process its emotions.

# %%
from langchain_groq import ChatGroq
model_2 = ChatGroq(model="llama-3.1-8b-instant")
response=model_2.invoke("crops grown in Assam")
print(response.content)
# Out:
# Assam is a major agricultural state in India and is known for its rich fertile soil and favorable climate. Here are some of the major crops grown in Assam:
#
# 1. **Tea**: Assam is the second-largest tea-producing state in India, accounting for about 75% of India's tea production. Tea is grown in the Brahmaputra Valley and the Barak Valley.
# 2. **Rice**: Rice is the staple food crop in Assam and is grown in the Brahmaputra Valley, the Barak Valley, and the hill districts.
# 3. **Jute**: Assam is the largest producer of jute in India, accounting for about 80% of the country's jute production.
# 4. **Maize**: Maize is another major crop grown in Assam, particularly in the Brahmaputra Valley and the Barak Valley.
# 5. **Potato**: Assam is a major producer of potatoes in India, with the majority of the crop being grown in the Brahmaputra Valley.
# 6. **Sugarcane**: Sugarcane is grown in the Brahmaputra Valley and the Barak Valley, with the majority of the crop being used for sugar production.
# 7. **Millet**: Millets such as ragi, jowar, and bajra are grown in the hill districts of Assam.
# 8. **Pulses**: Pulses such as gram, lentil, and pea are grown in the Brahmaputra Valley and the Barak Valley.
# 9. **Tobacco**: Tobacco is grown in the Brahmaputra Valley and the Barak Valley, with the majority of the crop being used for cigarette production.
# 10. **Oilseeds**: Oilseeds such as mustard, til, and linseed are grown in the Brahmaputra Valley and the Barak Valley.
# 11. **Fruits**: Assam is known for its production of fruits such as oranges, bananas, mangoes, and pineapples.
# 12. **Spices**: Assam is a major producer of spices such as ginger, turmeric, and cardamom.
# 13. **Coconut**: Coconut is grown in the Brahmaputra Valley and the Barak Valley.
# 14. **Areca nut**: Areca nut is grown in the Brahmaputra Valley and the Barak Valley.
# 15. **Chillies**: Chillies are grown in the Brahmaputra Valley and the Barak Valley.
#
# These are some of the major crops grown in Assam, and the state has a high agricultural potential due to its fertile soil and favorable climate.

# %% [markdown]
# ## Streaming and Batch

# %%
for chunk in model_2.stream("What are the benefits of using Groq's LLMs?"):
    print(chunk.text,end="", flush=True)
# Out:
# Groq is a technology company specializing in high-performance computing, particularly in the development of large language models (LLMs). Groq's LLMs are designed to provide several benefits, including:
#
# 1. **Faster Training and Inference Times**: Groq's custom-designed hardware accelerators are optimized for large language models, allowing for significantly faster training and inference times compared to traditional computing architectures.
#
# 2. **Scalability**: Groq's LLMs can handle massive amounts of data and scale to meet the needs of complex applications, such as natural language processing (NLP) and text generation.
#
# 3. **Energy Efficiency**: Groq's hardware accelerators are designed to be energy-efficient, which reduces the carbon footprint and operational costs associated with running large language models.
#
# 4. **Real-time Processing**: Groq's LLMs can process and respond to user inputs in real-time, making them suitable for applications such as chatbots, virtual assistants, and content generation.
#
# 5. **Advanced NLP Capabilities**: Groq's LLMs are designed to handle complex NLP tasks, such as text classification, sentiment analysis, and language translation, with high accuracy and speed.
#
# 6. **Customizability**: Groq's LLMs can be fine-tuned and customized to meet the specific needs of an application or industry, allowing for tailored solutions and improved performance.
#
# 7. **Integration with Existing Systems**: Groq's LLMs can be integrated with existing systems and frameworks, making it easier to deploy and integrate into existing applications.
#
# 8. **Security**: Groq's LLMs are designed with security in mind, incorporating measures such as data encryption and access controls to protect sensitive information.
#
# While I do not have any information on the current status of Groq's LLMs, these benefits are expected as per the previous research about their hardware accelerators, and this is a good starting point for understanding what Groq's LLMs could potentially offer.

# %%
responses=model_2.batch(
    [
        "what is ExpressJs uses in creating web pages?",
        "what is lightweight models in grok?",
        "How an airplane fly?"
    ]
)
for response in responses:
    print(response.content)
# Out:
# **Express.js: A Node.js Framework for Building Web Applications**
#
# Express.js is a popular, open-source JavaScript framework for building web applications and APIs. It is designed to provide a flexible and modular way to create web servers, allowing developers to build scalable, high-performance, and maintainable applications.
#
# **Key Features of Express.js:**
#
# 1. **Routing**: Express.js provides a robust routing system that allows developers to define routes for handling HTTP requests.
# 2. **Middleware**: Express.js uses middleware functions to handle requests and responses, making it easy to add functionality to the application.
# 3. **Template Engine**: Express.js supports several template engines, including EJS, Pug, and Handlebars, making it easy to render dynamic templates.
# 4. **Request and Response Objects**: Express.js provides a rich set of objects for handling requests and responses, including the `req` and `res` objects.
# 5. **Error Handling**: Express.js provides built-in error handling mechanisms, making it easy to catch and handle errors.
#
# **Common Use Cases for Express.js:**
#
# 1. **Building RESTful APIs**: Express.js is well-suited for building RESTful APIs, with its robust routing system and support for middleware.
# 2. **Creating Web Applications**: Express.js can be used to build web applications, including single-page applications (SPAs) and multi-page applications.
# 3. **Handling Webhooks**: Express.js can be used to handle webhooks, which are callbacks triggered by external services.
#
# **Example Code:**
#
# ```javascript
# const express = require('express');
# const app = express();
#
# // Define a route for handling GET requests
# app.get('/', (req, res) => {
#   res.send('Hello World!');
# });
#
# // Start the server
# const port = 3000;
# app.listen(port, () => {
#   console.log(`Server started on port ${port}`);
# });
# ```
#
# **Real-World Applications of Express.js:**
#
# 1. **Netflix**: Express.js is used by Netflix to build its API.
# 2. **LinkedIn**: LinkedIn uses Express.js to build its API.
# 3. **Uber**: Uber uses Express.js to build its API.
# 4. **Pinterest**: Pinterest uses Express.js to build its API.
#
# **Best Practices for Using Express.js:**
#
# 1. **Use a consistent naming convention**: Use a consistent naming convention for routes and middleware functions.
# 2. **Use middleware functions**: Use middleware functions to handle requests and responses.
# 3. **Use a template engine**: Use a template engine to render dynamic templates.
# 4. **Handle errors**: Handle errors using the built-in error handling mechanisms.
# 5. **Follow the MVC pattern**: Follow the Model-View-Controller (MVC) pattern to separate concerns and make the code more maintainable.
# In the context of the Grok framework (a Python library used for building event-driven applications, such as message queues and web services), a lightweight model is a way to represent data in a simple and efficient manner.
#
# In Grok, a model typically has the following characteristics:
#
# 1. **Simple**: Lightweight models are designed to be simple and easy to understand.
# 2. **Efficient**: They are optimized for performance and use minimal resources.
# 3. **Flexible**: Lightweight models can be easily extended or modified as needed.
#
# A lightweight model in Grok is typically implemented using a dictionary or a simple object with attributes. This approach allows for easy data access and manipulation while keeping the overhead of complex object relationships or database schema management to a minimum.
#
# Some common use cases for lightweight models in Grok include:
#
# 1. **Representing simple data structures**: Such as user profiles, product information, or other types of metadata.
# 2. **Handling transient data**: Like temporary storage for intermediate results or caching data.
# 3. **Implementing event-driven processing**: Where lightweight models can be used to represent events or messages being processed.
#
# Here's an example of a simple lightweight model in Grok:
# ```python
# from grokcore.component import Context
#
# class User(Context):
#     def __init__(self, id, name, email):
#         self.id = id
#         self.name = name
#         self.email = email
#
#     def __repr__(self):
#         return f"User(id={self.id}, name={self.name}, email={self.email})"
#
# # Usage:
# user = User(1, "John Doe", "john@example.com")
# print(user)  # Output: User(id=1, name=John Doe, email=john@example.com)
# ```
# In this example, the `User` model is a lightweight representation of a user entity, with attributes for `id`, `name`, and `email`. The model is simple, efficient, and flexible, making it suitable for use in a variety of applications.
# An airplane flies by using the principles of aerodynamics, which is the interaction between air and the airplane's shape. Here's a step-by-step explanation:
#
# 1. **Lift**: Lift is the upward force that opposes the weight of the airplane and keeps it flying. It's created by the wings, which are designed to produce a difference in air pressure above and below them. As the plane moves forward, the air flows over and under the curved surface of the wing, creating a pressure difference. The air pressure above the wing is lower than the air pressure below it, resulting in an upward force (lift) that counteracts the weight of the plane.
#
# 2. **Wing Shape**: The shape of the wing is crucial for creating lift. The wing is curved on top and flat on the bottom. As the air flows over the curved surface, it must travel faster to follow the shape of the wing, which creates a region of lower air pressure above the wing. The flat bottom of the wing, on the other hand, allows the air to flow smoothly over it, creating a region of higher air pressure below the wing.
#
# 3. **Angle of Attack**: The angle at which the wing meets the oncoming air is critical for creating lift. As the plane moves forward, the wing is tilted slightly upward, which creates a greater pressure difference between the top and bottom surfaces of the wing. This greater pressure difference results in a greater lift force.
#
# 4. **Control Surfaces**: The airplane has control surfaces, such as ailerons, elevators, and rudder, which are used to control the direction of the plane. The ailerons control roll (rotation around the longitudinal axis), the elevators control pitch (rotation around the lateral axis), and the rudder controls yaw (rotation around the vertical axis).
#
# 5. **Thrust**: Thrust is the forward force that propels the airplane through the air. It's created by the airplane's engines, which produce a stream of high-speed air that exits the back of the plane. As the air exits the engine, it produces a forward force that propels the plane forward.
#
# 6. **Combining Forces**: When the lift and thrust forces are balanced, the airplane is in steady, level flight. As the pilot adjusts the control surfaces, the airplane can change direction, climb, or descend.
#
# In summary, an airplane flies by using the principles of aerodynamics to create lift and thrust. The shape of the wing, angle of attack, control surfaces, and thrust all work together to create the force necessary for the airplane to fly.
